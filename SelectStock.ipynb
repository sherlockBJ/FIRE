# %%
import qstock as qs
# 获取实时行情
qs.wencai('营业收入增长率>10%;营业利润增长率>20%;加权净资产收益率>15%;总资产报酬率>5%，非ST，上市时间大于1年')
# Out:
#          股票代码  股票简称    最新价         最新涨跌幅  营业收入同比增长率[20240930]  \
# 0   300492.SZ  华图山鼎  78.75  -2.777777778          4702.212900
# 1   688506.SH  百利天恒  203.4   1.801801802          1399.222319
# 2   601127.SH   赛力斯  130.7   0.414874001           539.242894
# 3   001309.SZ   德明利  83.69  -0.357185379           268.449710
# 4   600149.SH  廊坊发展   5.12  -0.775193798           171.889552
# ..        ...   ...    ...           ...                  ...
# 74  300705.SZ  九典制药  24.98  -4.692865319            13.363200
# 75  002535.SZ  林州重机   4.45  -0.224215247            12.867037
# 76  300002.SZ  神州泰岳  12.26  -3.692065986            11.417583
# 77  000953.SZ  河化股份   6.66   1.524390244            10.164923
# 78  600285.SH  羚锐制药  21.44  -1.061375173            10.066112
#
#    营业利润(同比增长率)[20240930]  净资产收益率roe(加权,公布值)[20240930] 总资产报酬率roa[20240930]  \
# 0              3103.1168                        47.18             12.2017
# ...
