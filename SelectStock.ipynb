# %%
import tushare as ts
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import jieba
import jieba.analyse
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

#正常显示画图时出现的中文和负号
from pylab import mpl
mpl.rcParams['font.sans-serif']=['SimHei']
mpl.rcParams['axes.unicode_minus']=False

token = "91e924ed1b80bc0b25d7e50ea6546744750ba9665f81d70b5b0cdf76"
pro = ts.pro_api(token)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f8a23d1b595b4c04812c841fd7b7b592" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f8a23d1b595b4c04812c841fd7b7b592 = echarts.init(
#                     document.getElementById('f8a23d1b595b4c04812c841fd7b7b592'), 'white', {renderer: 'canvas'});
#                 var option_f8a23d1b595b4c04812c841fd7b7b592 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "candlestick",
#             "name": "\u65e5K\u7ebf\u56fe",
#             "coordinateSystem": "cartesian2d",
#             "colorBy": "series",
#             "legendHoverLink": true,
#             "hoverAnimation": true,
#             "data": [
#                 null,
#                 null,
#                 null,
#                 null
#             ],
#             "selectedMode": false,
#             "large": false,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u65e5K\u7ebf\u56fe"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": true,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "animation": true,
#             "animationThreshold": 2000,
#             "animationDuration": 1000,
#             "animationEasing": "cubicOut",
#             "animationDelay": 0,
#             "animationDurationUpdate": 300,
#             "animationEasingUpdate": "cubicOut",
#             "animationDelayUpdate": 0,
#             "data": [
#                 "20240102",
#                 "20240103",
#                 "20240104",
#                 "20240105"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": true,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "animation": true,
#             "animationThreshold": 2000,
#             "animationDuration": 1000,
#             "animationEasing": "cubicOut",
#             "animationDelay": 0,
#             "animationDurationUpdate": 300,
#             "animationEasingUpdate": "cubicOut",
#             "animationDelayUpdate": 0
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_f8a23d1b595b4c04812c841fd7b7b592.setOption(option_f8a23d1b595b4c04812c841fd7b7b592);
#         });
#     </script>

# %% [markdown]
# # 宏观经济指标
# ## GDP

# %%
import qstock as qs
gdp = qs.macro_data('gdp')
gdp.head(3)
# Out:
#             季度    国内生产总值     第一产业      第二产业      第三产业  国内生产总值同比  第一产业同比  \
# 0  2024年第1-3季度  949745.7  57733.1  361361.6  530651.1       4.8     3.4
# 1  2024年第1-2季度  616836.0  30660.0  236529.9  349646.1       5.0     3.5
# 2    2024年第1季度  296299.5  11538.4  109846.3  174914.7       5.3     3.3
#
#    第二产业同比  第三产业同比
# 0     5.4     4.7
# 1     5.8     4.6
# 2     6.0     5.0

# %%
cpi = qs.macro_data('cpi')
cpi.tail(3)
# Out:
#             月份  全国同比   全国当月  全国环比   全国累计  城市同比   城市当月  城市环比   城市累计  农村同比  \
# 200  2024年09月份   0.4  100.4   0.0  100.3   0.4  100.4  -0.1  100.2   0.6
# 201  2024年10月份   0.3  100.3  -0.3  100.3   0.2  100.2  -0.3  100.2   0.3
# 202  2024年11月份   0.2  100.2  -0.6  100.3   0.1  100.1  -0.6  100.2   0.2
#
#       农村当月  农村环比   农村累计
# 200  100.6   0.1  100.3
# 201  100.3  -0.3  100.3
# 202  100.2  -0.6  100.3

# %%
news = qs.news_data()
news.tail()
# Out:
#                                                    标题  \
# 45  【风口研报·公司】国内多家品牌方群雄逐鹿抢首发，分析师看好AI赋能下这一智能产品行业拐点已至...
# 46                                    石破茂内阁支持率降至36.5%
# 47
# 48                                苏丹武装冲突致该国约90%工业设施受损
# 49                              成本上升 欧盟巧克力价格平均上涨11.1%
#
#                                                    内容      发布时间        发布日期
# 45  ①国内多家品牌方群雄逐鹿抢首发，分析师看好AI赋能下这一智能产品行业拐点已至，公司提前布局并...  20:18:31  2024-12-15
# 46  【石破茂内阁支持率降至36.5%】财联社12月15日电，据共同社于12月14日至15日进行的...  20:46:37  2024-12-15
# 47                          财联社12月15日电，以色列将关闭驻爱尔兰大使馆。  20:59:04  2024-12-15
# 48  【苏丹武装冲突致该国约90%工业设施受损】财联社12月15日电，苏丹工业部部长马赫森·雅各布...  21:15:53  2024-12-15
# 49  【成本上升 欧盟巧克力价格平均上涨11.1%】财联社12月15日电，比利时是巧克力消费大国，...  21:25:44  2024-12-15
